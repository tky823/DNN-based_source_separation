# %%
# %%shell
# git clone https://github.com/tky823/DNN-based_source_separation.git

# %%
# %%shell
# cd "/content/DNN-based_source_separation/egs/musdb18"
# pip install -r requirements.txt

# %% [markdown]
# ## Training

# %%
# %%shell
# cd "/content/DNN-based_source_separation/egs/musdb18/d3net"
#
# musdb18_root="../../../dataset/musdb18" # Path to MUSDB18 dataset
# target='vocals' # 'drums', 'bass', 'other'
# exp_dir="/content/drive/MyDrive/Colab Notebooks/work/DNN-based_source_separation/egs/musdb18/d3net/exp"
#
# . ./train.sh --musdb18_root "${musdb18_root}" --exp_dir "${exp_dir}" --target "${target}" --config_path "./config/${target}.yaml"
# # . ./train.sh --musdb18_root "${musdb18_root}" --exp_dir "${exp_dir}" --target "${target}" --config_path "./config/${target}.yaml" --use_cuda 0

# %% [markdown]
# ## Resume Training

# %%
# %%shell
# cd "/content/DNN-based_source_separation/egs/musdb18/d3net"
#
# musdb18_root="../../../dataset/musdb18" # Path to MUSDB18 dataset
# target='vocals' # 'drums', 'bass', 'other'
# exp_dir="/content/drive/MyDrive/Colab Notebooks/work/DNN-based_source_separation/egs/musdb18/d3net/exp"
# continue_from="${exp_dir}/vocals/sr44100/patch256/mse/stft4096-1024_hann-window/b6_e100_adam-lr1e-3-decay0_clip5/seed111/model/last.pth"
#
# # . ./train.sh --musdb18_root "${musdb18_root}" --exp_dir "${exp_dir}" --target "${target}" --config_path "./config/${target}.yaml" --continue_from "${continue_from}"
