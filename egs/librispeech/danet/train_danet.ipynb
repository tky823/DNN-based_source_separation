# %%
# !git clone -b danet https://github.com/tky1117/DNN-based_source_separation.git

# %%
# !pip install soundfile # for Google colaboratory

# %%
from google.colab import drive
drive.mount("/content/drive")

# %% [markdown]
# ## Make dataset for 2 speakers

# %%
# %cd "/content/DNN-based_source_separation/egs/librispeech/common"

# %%
# !git pull

# %%
# !. ./prepare.sh "../../../dataset" 2

# %% [markdown]
# ## Training

# %%
# %cd "/content/DNN-based_source_separation/egs/librispeech/danet"

# %%
# !. ./train.sh "/content/drive/My Drive/Colab Notebooks/work/DNN-based_source_separation/egs/librispeech/danet/exp"

# %% [markdown]
# ## ResumeTraining

# %%
path = "/content/drive/My Drive/Colab Notebooks/work/DNN-based_source_separation/egs/librispeech/danet/exp/2mix/l2loss/hamming-window_ibm_threshold40/K20_H256_B4_H256_causal0_mask-sigmoid/b4_e100_rmsprop-lr1e-4-decay0/seed111/model/last.pth"

# %%
# !. ./train.sh "/content/drive/My Drive/Colab Notebooks/work/DNN-based_source_separation/egs/librispeech/danet/exp" "$path"
# Out:
# Namespace(batch_size=4, causal=0, continue_from='/content/drive/My Drive/Colab Notebooks/work/DNN-based_source_separation/egs/librispeech/danet/exp/2mix/l2loss/hamming-window_ibm_threshold40/K20_H256_B4_H256_causal0_mask-sigmoid/b4_e100_rmsprop-lr1e-4-decay0/seed111/model/last.pth', criterion='l2loss', embed_dim=20, epochs=100, fft_size=256, hidden_channels=256, hop_size=64, ideal_mask='ibm', loss_dir='/content/drive/My Drive/Colab Notebooks/work/DNN-based_source_separation/egs/librispeech/danet/exp/2mix/l2loss/hamming-window_ibm_threshold40/K20_H256_B4_H256_causal0_mask-sigmoid/b4_e100_rmsprop-lr1e-4-decay0/seed111/loss', lr=0.0001, mask_nonlinear='sigmoid', max_norm=None, model_dir='/content/drive/My Drive/Colab Notebooks/work/DNN-based_source_separation/egs/librispeech/danet/exp/2mix/l2loss/hamming-window_ibm_threshold40/K20_H256_B4_H256_causal0_mask-sigmoid/b4_e100_rmsprop-lr1e-4-decay0/seed111/model', n_sources=2, num_blocks=4, optimizer='rmsprop', overwrite=0, sample_dir='/content/drive/My Drive/Colab Notebooks/work/DNN-based_source_separation/egs/librispeech/danet/exp/2mix/l2loss/hamming-window_ibm_threshold40/K20_H256_B4_H256_causal0_mask-sigmoid/b4_e100_rmsprop-lr1e-4-decay0/seed111/sample', seed=111, sr=16000, threshold=40.0, train_json_path='../../../dataset/LibriSpeech/train-clean-100/train-100-2mix.json', use_cuda=1, valid_json_path='../../../dataset/LibriSpeech/dev-clean/valid-2mix.json', wav_root='../../../dataset/LibriSpeech', weight_decay=0.0, window_fn='hamming')
# Training dataset includes 83256 samples.
# Valid dataset includes 1710 samples.
# DANet(
#   (lstm): StackedLSTM(
#     (net): Sequential(
#       (0): LSTM(129, 128, batch_first=True, bidirectional=True)
#       (1): LSTM(256, 128, batch_first=True, bidirectional=True)
#       (2): LSTM(256, 128, batch_first=True, bidirectional=True)
#       (3): LSTM(256, 128, batch_first=True, bidirectional=True)
#     )
#   )
#   (fc): Linear(in_features=256, out_features=2580, bias=True)
