# %%
# %%shell
# git clone https://github.com/tky823/DNN-based_source_separation.git

# %%
# %%shell
# # for Google colaboratory
# pip install soundfile
# pip install mir_eval

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Make dataset for 2 speakers

# %%
# %%shell
# cd "/content/DNN-based_source_separation/egs/librispeech/common"
#
# . ./prepare.sh "../../../dataset" 2

# %% [markdown]
# ## Training

# %%
# %%shell
# cd "/content/DNN-based_source_separation/egs/librispeech/dprnn-tasnet"
#
# exp_dir="/content/drive/MyDrive/Colab Notebooks/work/DNN-based_source_separation/egs/librispeech/dprnn-tasnet/exp"
# # . ./train.sh --exp_dir "${exp_dir}"

# %% [markdown]
# ## Resume training

# %%
# %%shell
# cd "/content/DNN-based_source_separation/egs/librispeech/dprnn-tasnet"
#
# exp_dir="/content/drive/MyDrive/Colab Notebooks/work/DNN-based_source_separation/egs/librispeech/dprnn-tasnet/exp"
# continue_from="${exp_dir}/2mix/trainable-trainable/sisdr/N64_L16_F64_H128_K100_P50_B3/enc-relu_causal0_norm1_mask-sigmoid/b4_e100_adam-lr1e-3-decay0_clip0/seed111/model/last.pth"
# # . ./train.sh --exp_dir "${exp_dir}" --continue_from "${continue_from}"
