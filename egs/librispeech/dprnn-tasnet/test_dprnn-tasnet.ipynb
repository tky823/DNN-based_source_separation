# %%
# !git clone https://github.com/tky1117/DNN-based_source_separation.git

# %%
# !pip install soundfile # for Google colaboratory

# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
# %cd "/content/DNN-based_source_separation/egs/librispeech/common"

# %%
# !git pull

# %%
# !. ./prepare.sh "../../../dataset" 2

# %%
"""
    Download PESQ software from "https://www.itu.int/rec/T-REC-P.862-200102-I/en".
    Then, upload
        - dsp.c
        - dsp.h 
        - pesq.h
        - pesqdsp.c
        - pesqio.c
        - pesqmain.c
        - pesqmod.c
        - pesqpar.h
    for PESQ evaluation.
"""
 
from google.colab import files
uploaded = files.upload()

# %%
# !. ./test.sh "../dprnn_tasnet"

# %%
# %cd "/content/DNN-based_source_separation/egs/librispeech/dprnn_tasnet"

# %%
# !. ./test.sh "/content/drive/My Drive/Colab Notebooks/work/DNN-based_source_separation/egs/librispeech/dprnn_tasnet/exp"
