# %%
# !git clone https://github.com/tky823/DNN-based_source_separation.git

# %%
# %%shell
# # for Google colaboratory
# pip install soundfile
# pip install mir_eval

# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
# %cd "/content/DNN-based_source_separation/egs/librispeech/common"

# %%
# !chmod +x ./local/prepare_librispeech.py

# %%
# !. ./prepare.sh "../../../dataset" 2

# %%
"""
    Download PESQ software from "https://www.itu.int/rec/T-REC-P.862-200102-I/en".
    Then, upload
        - dsp.c
        - dsp.h 
        - pesq.h
        - pesqdsp.c
        - pesqio.c
        - pesqmain.c
        - pesqmod.c
        - pesqpar.h
    for PESQ evaluation.
"""
 
from google.colab import files
uploaded = files.upload()

# %%
# !. ./prepare_pesq.sh "../conv-tasnet"

# %%
# %cd "/content/DNN-based_source_separation/egs/librispeech/conv-tasnet"

# %%
# !. ./test.sh "/content/drive/My Drive/Colab Notebooks/work/DNN-based_source_separation/egs/librispeech/conv-tasnet/exp"
