# %%
# !git clone https://github.com/tky1117/DNN-based_source_separation.git

# %%
# !pip install soundfile # for Google colaboratory

# %%
from google.colab import drive
drive.mount("/content/drive")

# %% [markdown]
# ## Make dataset for 2 speakers

# %%
# %cd "/content/DNN-based_source_separation/egs/librispeech/common"
# Out:
# /content/DNN-based_source_separation/egs/librispeech/common

# %%
# !git pull

# %%
# !chmod +x ./local/prepare_librispeech.py

# %%
# !. ./prepare.sh "../../../dataset" 2

# %%
# %cd "/content/DNN-based_source_separation/egs/librispeech/dprnn_tasnet"

# %% [markdown]
# ## Training

# %%
# !. ./train.sh "/content/drive/My Drive/Colab Notebooks/work/DNN-based_source_separation/egs/librispeech/dprnn_tasnet/exp"

# %% [markdown]
# ## Resume training

# %%
# path = "/content/drive/My Drive/Colab Notebooks/work/DNN-based_source_separation/egs/librispeech/dprnn_tasnet/exp/2mix/trainable-trainable/sisdr/N64_L16_H256_K100_P50_B3/enc-relu_dilated1_separable1_causal0_norm1_mask-sigmoid/b4_e100_adam-lr1e-3-decay0_clip5/seed111/model/best.pth"

# %%
# !. ./train.sh "/content/drive/My Drive/Colab Notebooks/work/DNN-based_source_separation/egs/librispeech/dprnn_tasnet/exp" "$path"
