# %%
# %%shell
# git clone https://github.com/tky823/DNN-based_source_separation.git

# %%
from google.colab import drive
drive.mount("/content/drive")

# %% [markdown]
# ## Training

# %%
# %%shell
# cd "/content/DNN-based_source_separation/egs/dsd100/conv-tasnet"
#
# exp_dir="/content/drive/My Drive/Colab Notebooks/work/DNN-based_source_separation/egs/dsd100/conv-tasnet/exp"
# # . ./train.sh --exp_dir "${exp_dir}"

# %% [markdown]
# ## Resume Training

# %%
# %%shell
# cd "/content/DNN-based_source_separation/egs/dsd100/conv-tasnet"
#
# exp_dir="/content/drive/My Drive/Colab Notebooks/work/DNN-based_source_separation/egs/dsd100/conv-tasnet/exp"
# continue_from="${exp_dir}/[vocals,bass]/sr16000/trainable-trainable/sisdr/N64_L16_B128_H256_Sc128_P3_X6_R3/enc-relu_dilated1_separable1_causal0_prelu_norm1_mask-sigmoid/b4_e100_adam-lr1e-3-decay0_clip5/seed111/model/last.pth"
#
# # . ./train.sh --exp_dir "${exp_dir}" --continue_from "${continue_from}"
