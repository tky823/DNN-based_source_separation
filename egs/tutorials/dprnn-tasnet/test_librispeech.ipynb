# %%
# %%shell
# git clone https://github.com/tky823/DNN-based_source_separation.git

# %%
# for google drive
# from google.colab import drive
# drive.mount("/content/drive")

# %%
# %%shell
# cd "/content/DNN-based_source_separation/egs/tutorials"
#
# pip install -r requirements.txt -q
#
# cd "/content/DNN-based_source_separation/egs/tutorials/common"
#
# . ./prepare_librispeech.sh \
# --librispeech_root "../../../dataset/LibriSpeech" \
# --n_sources 2

# %%
# %cd "/content/DNN-based_source_separation/egs/tutorials/common"
# Out:
# /content/DNN-based_source_separation/egs/librispeech/common

# %%
"""
    Download PESQ software from "https://www.itu.int/rec/T-REC-P.862-200102-I/en".
    Then, upload
        - dsp.c
        - dsp.h 
        - pesq.h
        - pesqdsp.c
        - pesqio.c
        - pesqmain.c
        - pesqmod.c
        - pesqpar.h
    for PESQ evaluation.
"""
 
from google.colab import files
uploaded = files.upload()

# %%
# %%shell
# cd "/content/DNN-based_source_separation/egs/tutorials/common"
#
# . ./prepare_pesq.sh \
# --out_dir "../dprnn-tasnet"

# %%
# %%shell
# export TZ="UTC-9"
#
# cd "/content/DNN-based_source_separation/egs/tutorials/dprnn-tasnet"
#
# exp_dir="./exp"
# # exp_dir="/content/drive/MyDrive/Colab Notebooks/work/DNN-based_source_separation/egs/tutorials/dprnn-tasnet/exp" # for google drive
#
# . ./test.sh \
# --exp_dir "${exp_dir}"
