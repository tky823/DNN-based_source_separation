# %%
# %%shell
# git clone https://github.com/tky823/DNN-based_source_separation.git

# %%
from google.colab import drive
drive.mount("/content/drive")

# %% [markdown]
# ## Make dataset for 2 speakers

# %%
# %%shell
# cd "/content/DNN-based_source_separation/egs/tutorials"
#
# pip install -r requirements.txt
#
# cd "/content/DNN-based_source_separation/egs/tutorials/common"
#
# . ./prepare_librispeech.sh --dataset_root "../../../dataset" --n_sources 2

# %% [markdown]
# ## Training

# %%
# %%shell
# export TZ="UTC-9"
#
# cd "/content/DNN-based_source_separation/egs/tutorials/dprnn-tasnet"
#
# exp_dir="/content/drive/MyDrive/Colab Notebooks/work/DNN-based_source_separation/egs/tutorials/dprnn-tasnet/exp"
# # . ./train.sh --exp_dir "${exp_dir}"

# %% [markdown]
# ## Resume training

# %%
# %%shell
# export TZ="UTC-9"
#
# cd "/content/DNN-based_source_separation/egs/tutorials/dprnn-tasnet"
#
# exp_dir="/content/drive/MyDrive/Colab Notebooks/work/DNN-based_source_separation/egs/tutorials/dprnn-tasnet/exp"
# continue_from="${exp_dir}/2mix/trainable-trainable/sisdr/N64_L16_F64_H128_K100_P50_B3/enc-relu_causal0_norm1_mask-sigmoid/b4_e100_adam-lr1e-3-decay0_clip0/seed111/model/last.pth"
# # . ./train.sh --exp_dir "${exp_dir}" --continue_from "${continue_from}"
