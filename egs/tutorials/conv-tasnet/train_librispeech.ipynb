# %%
# %%shell
# git clone https://github.com/tky823/DNN-based_source_separation.git

# %%
# for google drive
# from google.colab import drive
# drive.mount("/content/drive")

# %% [markdown]
# ## Make dataset for 2 speakers

# %%
# %%shell
# cd "/content/DNN-based_source_separation/egs/tutorials"
#
# pip install -r requirements.txt -q
#
# cd "/content/DNN-based_source_separation/egs/tutorials/common"
#
# . ./prepare_librispeech.sh \
# --librispeech_root "../../../dataset/LibriSpeech" \
# --n_sources 2

# %% [markdown]
# ## Training

# %%
# %%shell
# export TZ="UTC-9"
#
# cd "/content/DNN-based_source_separation/egs/tutorials/conv-tasnet"
#
# exp_dir="./exp"
# # exp_dir="/content/drive/MyDrive/Colab Notebooks/work/DNN-based_source_separation/egs/tutorials/conv-tasnet/exp" # for google drive
#
# . ./train.sh \
# --exp_dir "${exp_dir}"

# %% [markdown]
# ## Resume Training

# %%
# %%shell
# export TZ="UTC-9"
#
# cd "/content/DNN-based_source_separation/egs/tutorials/conv-tasnet"
#
# exp_dir="./exp"
# # exp_dir="/content/drive/MyDrive/Colab Notebooks/work/DNN-based_source_separation/egs/tutorials/conv-tasnet/exp" # for google drive
# continue_from="${exp_dir}/2mix/trainable-trainable/sisdr/N64_L16_B128_H256_Sc128_P3_X6_R3/enc-relu_dilated1_separable1_causal0_prelu_norm1_mask-sigmoid/b4_e100_adam-lr1e-3-decay0_clip5/seed111/model/last.pth"
#
# . ./train.sh \
# --exp_dir "${exp_dir}" \
# --continue_from "${continue_from}"
