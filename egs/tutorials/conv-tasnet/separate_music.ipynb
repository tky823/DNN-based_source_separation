# %% [markdown]
# # Separate music signals using Conv-TasNet

# %%
# %%shell
# git clone https://github.com/tky823/DNN-based_source_separation.git

# %%
# %%shell
# cd "/content/DNN-based_source_separation/egs/musdb18"
#
# # Build environment
# pip install -r requirements.txt -q
#
# cd "/content/DNN-based_source_separation/egs/tutorials/conv-tasnet"
#
# # Download pretrained model
# model_name="sr44100_L20" # or "sr44100_L64"
#
# . ./prepare_mss-model.sh --model_name "${model_name}"

# %%
# %%shell
# cd "/content/DNN-based_source_separation/egs/musdb18"
#
# git pull origin beta

# %%
model_path = "/content/DNN-based_source_separation/egs/tutorials/conv-tasnet/model/last.pth"

# %%
import os
import sys
sys.path.append("/content/DNN-based_source_separation/src")
sys.path.append("/content/DNN-based_source_separation/egs/tutorials/conv-tasnet/src")

# %%
from google.colab import files

# %%
uploaded = files.upload()
file_paths = [
    key for key in uploaded.keys()
]
out_dirs = [
    os.path.join("outputs", os.path.splitext(file_path)[0]) for file_path in file_paths
]

# %%
from adhoc_utils import separate_by_conv_tasnet

# %%
estimated_paths = separate_by_conv_tasnet(model_path, file_paths, out_dirs)

# %%
import IPython.display as ipd

# %%
#@title Choose a separate track and target

track =  1#@param {type:"number"}
target = 'bass' #@param ["bass", "drums", "other", "vocals"]

assert track <= len(file_paths), "Invalid track is chosen."

print("Track title: {}, target: {}".format(file_paths[track - 1], target))

ipd.Audio(estimated_paths[track - 1][target])

# %%
# %%shell
# zip "outputs.zip" -r "outputs/"

# %%
# Download separation results
files.download("outputs.zip")
