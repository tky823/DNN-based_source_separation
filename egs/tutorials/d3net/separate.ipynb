# %%
# %%shell
# git clone https://github.com/tky823/DNN-based_source_separation.git

# %%
# %%shell
# cd "/content/DNN-based_source_separation/egs/tutorials/d3net"
#
# # build environment
# pip install -r requirements.txt -q
#
# # load pretrained model
# model_id="1eg9L02MHBGosqouytuKRDZhH6A-flb_Z" # trained for only 1 epoch
#
# . ./prepare.sh --model_id "${model_id}"

# %%
# %cd "/content/DNN-based_source_separation/egs/tutorials/d3net"

# %%
model_paths = {
    'drums': "/content/DNN-based_source_separation/egs/tutorials/d3net/model/drums.pth",
    'bass': "/content/DNN-based_source_separation/egs/tutorials/d3net/model/bass.pth",
    'other': "/content/DNN-based_source_separation/egs/tutorials/d3net/model/other.pth",
    'vocals': "/content/DNN-based_source_separation/egs/tutorials/d3net/model/vocals.pth"
}

# %%
import os
import sys
sys.path.append("/content/DNN-based_source_separation/src")
sys.path.append("/content/DNN-based_source_separation/egs/tutorials/d3net/src")

# %%
from google.colab import files

# %%
uploaded = files.upload()
wav_paths = [
    key for key in uploaded.keys()
]
out_dirs = [
    os.path.splitext(wav_path)[0] for wav_path in wav_paths
]

# %%
from adhoc_utils import separate_by_d3net

# %%
estimated_paths = [
    separate_by_d3net(wav_path, model_paths, out_dir) for wav_path, out_dir in zip(wav_paths, out_dirs)
]

# %%
import IPython.display as ipd

# %%
#@title Choose a separate track and target

track =  1#@param {type:"number"}
target = 'bass' #@param ["bass", "drums", "other", "vocals"]

assert track <= len(wav_paths), "Invalid track is chosen."

print("Track title: {}, target: {}".format(wav_paths[track - 1], target))

ipd.Audio(estimated_paths[track - 1][target])
