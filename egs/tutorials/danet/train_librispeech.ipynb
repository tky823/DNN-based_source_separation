# %%
# %%shell
# git clone https://github.com/tky823/DNN-based_source_separation.git

# %%
from google.colab import drive
drive.mount("/content/drive")

# %% [markdown]
# ## Make dataset for 2 speakers

# %%
# %%shell
# cd "/content/DNN-based_source_separation/egs/tutorials"
#
# pip install -r requirements.txt
#
# cd "/content/DNN-based_source_separation/egs/tutorials/common"
#
# . ./prepare_librispeech.sh --dataset_root "../../../dataset" --n_sources 2

# %% [markdown]
# ## Training

# %%
# %%shell
# export TZ="UTC-9"
#
# cd "/content/DNN-based_source_separation/egs/tutorials/danet"
#
# exp_dir="/content/drive/MyDrive/Colab Notebooks/work/DNN-based_source_separation/egs/tutorials/danet/exp"
# # . ./train.sh --exp_dir "${exp_dir}"

# %% [markdown]
# ## ResumeTraining

# %%
# %%shell
# export TZ="UTC-9"
#
# cd "/content/DNN-based_source_separation/egs/tutorials/danet"
#
# exp_dir="/content/drive/MyDrive/Colab Notebooks/work/DNN-based_source_separation/egs/tutorials/danet/exp"
# continue_from="${exp_dir}/2mix/l2loss/stft256-64_hamming-window_ibm_threshold40/K20_H256_B4_causal0_mask-sigmoid/b4_e100_rmsprop-lr1e-4-decay0/seed111/model/last.pth"
# # . ./train.sh --exp_dir "${exp_dir}" --continue_from "${continue_from}"
