# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %%bash
# git clone "https://github.com/tky823/DNN-based_source_separation.git"

# %%
# %%shell
# cd "./DNN-based_source_separation/egs/tutorials/vae"
#
# exp_dir="/content/drive/MyDrive/Colab Notebooks/work/DNN-based_source_separation/egs/tutorials/vae/exp"
#
# . ./train_mnist.sh \
# --exp_dir "${exp_dir}" \
# --use_cuda 0
